# %% [markdown]
# <a href="https://colab.research.google.com/github/Yewon9/STT_JEJU/blob/main/eda_sub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pydub

# %%
import pandas as pd
from pydub import AudioSegment
from tqdm import tqdm
import matplotlib.pyplot as plt
import librosa
import numpy as np
import seaborn as sns
import re

# %%
df = pd.read_csv('df_eda.csv')
df
# Out:
#                                                     Path  \
# 0      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 1      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 2      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 3      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 4      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# ...                                                  ...
# 11989  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11990  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11991  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11992  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11993  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
#
#                                                     Text  \
# 0      여름에 보양식은 그 동네에서 보면 그 자리들 잡아가지고 된장에 풀어가지고 생된장에 ...
# 1      태풍은 나 중학교 땐가 정확하게 기억은 잘 안 나는디 옛날에 해가지고는 엄청나게 사...
# 2      그추룩헹은에 이제 제사 지낸 지가 한 이제 오 년 정도 됐신디예 어떵 하다 보니까 ...
# ...

# %%
over_50_seconds = df[df['Audio_Length'] <= 50]
print(f"50초 이상인 데이터 개수: {len(over_50_seconds)}")
# Out:
# 50초 이상인 데이터 개수: 9809

# %%
df_filtered = df[df['Audio_Length'] <= 50]
df_filtered
# Out:
#                                                     Path  \
# 0      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 1      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 3      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 4      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 5      /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# ...                                                  ...
# 11989  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11990  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11991  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11992  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11993  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
#
#                                                     Text  \
# 0      여름에 보양식은 그 동네에서 보면 그 자리들 잡아가지고 된장에 풀어가지고 생된장에 ...
# 1      태풍은 나 중학교 땐가 정확하게 기억은 잘 안 나는디 옛날에 해가지고는 엄청나게 사...
# 3      어 여기는 지금 농작물은 농사를 뭐 밭농사랑 뭐 과수원 같은 거 많이 하니까 뭐 이...
# ...

# %%
df_filtered = df[df['Text_Length'] <= 100]
df_filtered
# Out:
#                                                     Path  \
# 10     /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 94     /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 101    /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 104    /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 105    /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# ...                                                  ...
# 11989  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11990  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11991  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11992  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 11993  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
#
#                                                     Text  \
# 10        게매 여행 안 다녀보니까니 식구들하고 가면은 좀 볼거리 먹을거리로 가문 좋지 않으카
# 94     한 자식은 한 세 명 정도 있으면 좋을 거 닮은디 좀 나라도 부강허게 만들 수 있을...
# 101       새순이 날 때 봄이 왓덴 생각 들고 옷이 얇아지고 봄에는 놀러도 다니고 일도 허주게
# ...

# %%
sampled_data = df_filtered.sample(n=5000, random_state=42)
sampled_data
# Out:
#                                                     Path  \
# 3559   /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 8797   /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 8122   /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 7939   /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 6222   /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# ...                                                  ...
# 10984  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 5518   /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 10690  /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
# 6244   /content/drive/MyDrive/JEJU/data/wav/TL_02/say...
# 9010   /content/drive/MyDrive/JEJU/data/wav/VL_01/st_...
#
#                                                     Text  \
# 3559   옛날에 다 온돌방 썼지 옛날에싸 다 저기 불 떼어가지고 옛날 불 떼어서 그게 다 온...
# 8797                        전복도 맛 좋주만 그 게우 놩 멘든 젓도 맛 좋주게
# 8122                                    보릴 무껑 눌엇단 태작을 헌다
# ...

# %%
sampled_data.to_csv('sampled_dataset.csv', index=False, encoding = 'utf-8-sig')
